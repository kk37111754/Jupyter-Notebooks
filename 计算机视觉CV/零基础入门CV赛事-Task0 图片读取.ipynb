# %% [markdown]
# # 庖丁解牛
#
# ![OuuvDC](https://upiclw.oss-cn-beijing.aliyuncs.com/uPic/OuuvDC.jpg)

# %%
import pandas as pd
data = pd.read_csv('mchar_data_list_0515.csv')
data
# Out:
#                         file      size  \
# 0            mchar_train.zip  345.91MB
# 1           mchar_train.json    3.16MB
# 2              mchar_val.zip  200.16MB
# 3             mchar_val.json    1.03MB
# 4           mchar_test_a.zip   370.6MB
# 5  mchar_sample_submit_A.csv  507.83KB
#
#                                                 link
# 0  http://tianchi-competition.oss-cn-hangzhou.ali...
# 1  http://tianchi-competition.oss-cn-hangzhou.ali...
# 2  http://tianchi-competition.oss-cn-hangzhou.ali...
# 3  http://tianchi-competition.oss-cn-hangzhou.ali...
# 4  http://tianchi-competition.oss-cn-hangzhou.ali...
# 5  http://tianchi-competition.oss-cn-hangzhou.ali...

# %%
# !wget http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_train.zip
# Out:
# --2022-04-12 19:42:14--  http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_train.zip
# 正在解析主机 tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)... 183.131.227.248
# 正在连接 tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)|183.131.227.248|:80... 已连接。
# 已发出 HTTP 请求，正在等待回应... 200 OK
# 长度：362711501 (346M) [application/zip]
# 正在保存至: “mchar_train.zip”
#
# mchar_train.zip     100%[===================>] 345.91M  14.7MB/s  用时 23s
#
# 2022-04-12 19:42:38 (14.8 MB/s) - 已保存 “mchar_train.zip” [362711501/362711501])

# %%
for durl in data['link']:
    print(durl)
# Out:
# http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_train.zip
# http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_train.json
# http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_val.zip
# http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_val.json
# http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_test_a.zip
# http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_sample_submit_A.csv

# %%
# !wget http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_train.json
# Out:
# --2022-04-12 19:41:30--  http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_train.json
# 正在解析主机 tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)... 183.131.227.248
# 正在连接 tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)|183.131.227.248|:80... 已连接。
# 已发出 HTTP 请求，正在等待回应... 200 OK
# 长度：3310747 (3.2M) [application/json]
# 正在保存至: “mchar_train.json”
#
# mchar_train.json    100%[===================>]   3.16M  6.63MB/s  用时 0.5s
#
# 2022-04-12 19:41:30 (6.63 MB/s) - 已保存 “mchar_train.json” [3310747/3310747])

# %%
# !wget http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_val.zip
# Out:
# --2022-04-12 19:41:31--  http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_val.zip
# 正在解析主机 tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)... 183.131.227.248
# 正在连接 tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)|183.131.227.248|:80... 已连接。
# 已发出 HTTP 请求，正在等待回应... 200 OK
# 长度：209887177 (200M) [application/zip]
# 正在保存至: “mchar_val.zip”
#
# mchar_val.zip       100%[===================>] 200.16M  14.1MB/s  用时 15s
#
# 2022-04-12 19:41:46 (13.6 MB/s) - 已保存 “mchar_val.zip” [209887177/209887177])

# %%
# !wget http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_val.json
# Out:
# --2022-04-12 19:41:47--  http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_val.json
# 正在解析主机 tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)... 183.131.227.248
# 正在连接 tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)|183.131.227.248|:80... 已连接。
# 已发出 HTTP 请求，正在等待回应... 200 OK
# 长度：1077984 (1.0M) [application/json]
# 正在保存至: “mchar_val.json”
#
# mchar_val.json      100%[===================>]   1.03M  3.43MB/s  用时 0.3s
#
# 2022-04-12 19:41:47 (3.43 MB/s) - 已保存 “mchar_val.json” [1077984/1077984])

# %%
# !wget http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_test_a.zip
# Out:
# --2022-04-12 19:41:47--  http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_test_a.zip
# 正在解析主机 tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)... 183.131.227.248
# 正在连接 tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)|183.131.227.248|:80... 已连接。
# 已发出 HTTP 请求，正在等待回应... 200 OK
# 长度：388603696 (371M) [application/zip]
# 正在保存至: “mchar_test_a.zip”
#
# mchar_test_a.zip    100%[===================>] 370.60M  16.1MB/s  用时 26s
#
# 2022-04-12 19:42:14 (14.0 MB/s) - 已保存 “mchar_test_a.zip” [388603696/388603696])

# %%
# !wget http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_sample_submit_A.csv
# Out:
# --2022-04-12 19:42:14--  http://tianchi-competition.oss-cn-hangzhou.aliyuncs.com/531795/mchar_sample_submit_A.csv
# 正在解析主机 tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)... 183.131.227.248
# 正在连接 tianchi-competition.oss-cn-hangzhou.aliyuncs.com (tianchi-competition.oss-cn-hangzhou.aliyuncs.com)|183.131.227.248|:80... 已连接。
# 已发出 HTTP 请求，正在等待回应... 200 OK
# 长度：520020 (508K) [text/csv]
# 正在保存至: “mchar_sample_submit_A.csv”
#
# mchar_sample_submit 100%[===================>] 507.83K  2.14MB/s  用时 0.2s
#
# 2022-04-12 19:42:14 (2.14 MB/s) - 已保存 “mchar_sample_submit_A.csv” [520020/520020])

# %%
# !ls
# Out:
# OpenCV.ipynb
# mchar_data_list_0515.csv
# mchar_sample_submit_A.csv
# mchar_test_a.zip
# mchar_train.json
# mchar_train.zip
# mchar_val.json
# mchar_val.zip
# 零基础入门 CV 赛事-Task1 赛题理解.ipynb
# 零基础入门CV-0.ipynb

# %%
# !unzip mchar_train.zip
# Out:
# Archive:  mchar_train.zip
#    creating: mchar_train/
#   inflating: mchar_train/018292.png
#    creating: __MACOSX/
#    creating: __MACOSX/mchar_train/
#   inflating: __MACOSX/mchar_train/._018292.png
#   inflating: mchar_train/028351.png
#   inflating: __MACOSX/mchar_train/._028351.png
#   inflating: mchar_train/008081.png
#   inflating: __MACOSX/mchar_train/._008081.png
#   inflating: mchar_train/027062.png
#   inflating: __MACOSX/mchar_train/._027062.png
#   inflating: mchar_train/021413.png
#   inflating: __MACOSX/mchar_train/._021413.png
#   inflating: mchar_train/010816.png
#   inflating: __MACOSX/mchar_train/._010816.png
#   inflating: mchar_train/004863.png
#   inflating: __MACOSX/mchar_train/._004863.png
#   inflating: mchar_train/025675.png
#   inflating: __MACOSX/mchar_train/._025675.png
#   inflating: mchar_train/023204.png
#   inflating: __MACOSX/mchar_train/._023204.png
#   inflating: mchar_train/012967.png
#   inflating: __MACOSX/mchar_train/._012967.png
# ...

# %%
from IPython.display import HTML, Image

def _src_from_data(data):
    """Base64 encodes image bytes for inclusion in an HTML img element"""
    img_obj = Image(data=data)
    for bundle in img_obj._repr_mimebundle_():
        for mimetype, b64value in bundle.items():
            if mimetype.startswith('image/'):
                return f'data:{mimetype};base64,{b64value}'

def gallery(images, row_height='auto'):
    """Shows a set of images in a gallery that flexes with the width of the notebook.
    
    Parameters
    ----------
    images: list of str or bytes
        URLs or bytes of images to display

    row_height: str
        CSS height value to assign to all images. Set to 'auto' by default to show images
        with their native dimensions. Set to a value like '250px' to make all rows
        in the gallery equal height.
    """
    figures = []
    for image in images:
        if isinstance(image, bytes):
            src = _src_from_data(image)
            caption = ''
        else:
            src = image
            caption = f'<figcaption style="font-size: 0.6em">{image}</figcaption>'
        figures.append(f'''
            <figure style="margin: 5px !important;">
              <img src="{src}" style="height: {row_height}">
              {caption}
            </figure>
        ''')
    return HTML(data=f'''
        <div style="display: flex; flex-flow: row wrap; text-align: center;">
        {''.join(figures)}
        </div>
    ''')

# %%
import os
from os import listdir
from os.path import isfile, join

cwd = os.getcwd()
onlyfiles = [os.path.join(cwd, f) for f in os.listdir(cwd) if os.path.isfile(os.path.join(cwd, f))]
print(onlyfiles)
# Out:
# ['/Users/sherry/juypter-notebook/计算机视觉CV/.DS_Store', '/Users/sherry/juypter-notebook/计算机视觉CV/零基础入门CV赛事-Task1 赛题理解.ipynb', '/Users/sherry/juypter-notebook/计算机视觉CV/零基础入门CV赛事-Task5 模型集成.ipynb', '/Users/sherry/juypter-notebook/计算机视觉CV/零基础入门CV赛事-Task3 字符识别模型.ipynb', '/Users/sherry/juypter-notebook/计算机视觉CV/零基础入门CV赛事-Task0 图片读取.ipynb', '/Users/sherry/juypter-notebook/计算机视觉CV/零基础入门CV赛事-Task4 模型训练与验证.ipynb', '/Users/sherry/juypter-notebook/计算机视觉CV/零基础入门CV赛事-Task6 代码总结.ipynb', '/Users/sherry/juypter-notebook/计算机视觉CV/OpenCV.ipynb', '/Users/sherry/juypter-notebook/计算机视觉CV/零基础入门CV赛事-Task2 数据读取与数据扩增.ipynb']

# %%
import os
from os import listdir
from os.path import isfile, join

cwd = './dataset/mchar_train/'
onlyfiles = [os.path.join(cwd, f) for f in os.listdir(cwd) if os.path.isfile(os.path.join(cwd, f))]
print(onlyfiles)
# Out:
# ['./dataset/mchar_train/018292.png', './dataset/mchar_train/028351.png', './dataset/mchar_train/008081.png', './dataset/mchar_train/027062.png', './dataset/mchar_train/021413.png', './dataset/mchar_train/010816.png', './dataset/mchar_train/004863.png', './dataset/mchar_train/025675.png', './dataset/mchar_train/023204.png', './dataset/mchar_train/012967.png', './dataset/mchar_train/023562.png', './dataset/mchar_train/025113.png', './dataset/mchar_train/021375.png', './dataset/mchar_train/029729.png', './dataset/mchar_train/028437.png', './dataset/mchar_train/019832.png', './dataset/mchar_train/027704.png', './dataset/mchar_train/006912.png', './dataset/mchar_train/021361.png', './dataset/mchar_train/028423.png', './dataset/mchar_train/027710.png', './dataset/mchar_train/019826.png', './dataset/mchar_train/006906.png', './dataset/mchar_train/012973.png', './dataset/mchar_train/023576.png', './dataset/mchar_train/024219.png', './dataset/mchar_train/025107.png', './dataset/mchar_train/02
# ...

# %%
# 注意这个设计，如果全部显示的话会出出现加载失败

print("总共大小 " + str(len(onlyfiles)))

files = onlyfiles[:10]

(gallery(files))
# Out:
# 总共大小 30000
#         <div style="display: flex; flex-flow: row wrap; text-align: center;">
#
#             <figure style="margin: 5px !important;">
#               <img src="./dataset/mchar_train/018292.png" style="height: auto">
#               <figcaption style="font-size: 0.6em">./dataset/mchar_train/018292.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="./dataset/mchar_train/028351.png" style="height: auto">
#               <figcaption style="font-size: 0.6em">./dataset/mchar_train/028351.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
#               <img src="./dataset/mchar_train/008081.png" style="height: auto">
#               <figcaption style="font-size: 0.6em">./dataset/mchar_train/008081.png</figcaption>
#             </figure>
#
#             <figure style="margin: 5px !important;">
# ...

# %%
# !pip3 install Pillow

# %%
# !pip install exif # 这个对我们的案例是没有效果的，这是读原始照片的，我们的照片都被处理过。
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.0/69.0 KB 234.4 kB/s eta 0:00:00a 0:00:01
# ...

# %%
from PIL import Image
from PIL.ExifTags import TAGS

# %%
# path to the image or video
imagename = "./mchar_train/004863.png"

# read the image data using PIL
image = Image.open(imagename)

# extract other basic metadata
info_dict = {
    "Filename": image.filename,
    "Image Size": image.size,
    "Image Height": image.height,
    "Image Width": image.width,
    "Image Format": image.format,
    "Image Mode": image.mode,
    "Image is Animated": getattr(image, "is_animated", False),
    "Frames in Image": getattr(image, "n_frames", 1)
}

for label,value in info_dict.items():
    print(f"{label:25}: {value}")
# Out:
# Filename                 : ./mchar_train/004863.png
# Image Size               : (142, 56)
# Image Height             : 56
# Image Width              : 142
# Image Format             : PNG
# Image Mode               : RGB
# Image is Animated        : False
# Frames in Image          : 1

# %%
from exif import Image
img_path = imagename
with open(img_path, 'rb') as src:
    img = Image(src)
    print (src.name, img)
# Out:
# ./mchar_train/004863.png <exif._image.Image object at 0x7f7fe1716dc0>

# %%
if img.has_exif:
    info = f"has the EXIF {img.exif_version}"
else:
    info = "does not contain any EXIF information"
    
print(f"Image {src.name}: {info}")
# Out:
# Image ./mchar_train/004863.png: does not contain any EXIF information

# %%
# extract EXIF data
exifdata = image.getexif()
exifdata

# %%
# iterating over all EXIF data fields
for tag_id in exifdata:
    # get the tag name, instead of human unreadable tag id
    tag = TAGS.get(tag_id, tag_id)
    data = exifdata.get(tag_id)
    # decode bytes 
    if isinstance(data, bytes):
        data = data.decode()
    print(f"{tag:25}: {data}")

# %%
def getInfoOfImage(imagename):

    resultList = []
    # read the image data using PIL
    image = Image.open(imagename)

    # extract other basic metadata
    info_dict = {
        "Filename": image.filename,
        "Image Size": image.size,
        "Image Height": image.height,
        "Image Width": image.width,
        "Image Format": image.format,
        "Image Mode": image.mode,
        "Image is Animated": getattr(image, "is_animated", False),
        "Frames in Image": getattr(image, "n_frames", 1)
    }

    for label,value in info_dict.items():
        resultList.append(value)
        
    return resultList

imagename = "./dataset/mchar_train/004863.png"
getInfoOfImage(imagename)
# Out:
# ['./mchar_train/004863.png', (142, 56), 56, 142, 'PNG', 'RGB', False, 1]

# %%
## 构建一个 DataFrame

dfList = []

for file in onlyfiles:
    dfList.append(getInfoOfImage(file))
    
print(len(dfList))
# Out:
# 30000

# %%
columns = ["Filename","Image Size","Image Height","Image Width",
           "Image Format","Image Mode","Image is Animated","Frames in Image"]

df = pd.DataFrame(dfList,columns =columns)
df
# Out:
#                        Filename  Image Size  Image Height  Image Width  \
# 0      ./mchar_train/018292.png    (64, 26)            26           64
# 1      ./mchar_train/028351.png   (109, 48)            48          109
# 2      ./mchar_train/008081.png    (42, 18)            18           42
# 3      ./mchar_train/027062.png    (52, 12)            12           52
# 4      ./mchar_train/021413.png  (213, 108)           108          213
# ...                         ...         ...           ...          ...
# 29995  ./mchar_train/019195.png    (81, 35)            35           81
# 29996  ./mchar_train/020714.png   (209, 90)            90          209
# 29997  ./mchar_train/028348.png   (183, 89)            89          183
# 29998  ./mchar_train/008098.png    (86, 41)            41           86
# 29999  ./mchar_train/001902.png    (99, 48)            48           99
#
#       Image Format Image Mode  Image is Animated  Frames in Image
# ...

# %%
df.describe()
# Out:
#        Image Height   Image Width  Frames in Image
# count  30000.000000  30000.000000          30000.0
# mean      57.230667    128.272333              1.0
# std       36.168890     80.525062              0.0
# min       12.000000     25.000000              1.0
# 25%       33.000000     72.000000              1.0
# 50%       47.000000    104.000000              1.0
# 75%       71.000000    158.000000              1.0
# max      501.000000    876.000000              1.0

# %%
import pandas_profiling

pandas_profiling.ProfileReport(df)
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.1.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2022-04-05 10:43:04.825009&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
